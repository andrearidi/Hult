# %% [markdown]
# <a href="https://colab.research.google.com/github/andrearidi/Hult/blob/main/DataCorrection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#read excel file
df = pd.read_excel("/content/rollingsales_bronx.xlsx") #preview data
df.head()
# Out:
#   Bronx Rolling Sales.  All Sales From January 2023 - December 2023  \
# 0  For sales prior to the Final Roll, Neighborhoo...
# 1  Building Class Category is based on Building C...
# 2  Note: Condominium and cooperative sales are on...
# 3                                            BOROUGH
# 4                                                  2
#
#      Unnamed: 1               Unnamed: 2            Unnamed: 3 Unnamed: 4  \
# 0           NaN                      NaN                   NaN        NaN
# 1           NaN                      NaN                   NaN        NaN
# 2           NaN                      NaN                   NaN        NaN
# 3  NEIGHBORHOOD  BUILDING CLASS CATEGORY  TAX CLASS AT PRESENT      BLOCK
# 4      BATHGATE  01 ONE FAMILY DWELLINGS                     1       3030
#
#   Unnamed: 5 Unnamed: 6                 Unnamed: 7        Unnamed: 8  \
# 0        NaN        NaN                        NaN               NaN
# ...

# %%
#we read the data in again but skill 3 rows this time
df = pd.read_excel("/content/rollingsales_bronx.xlsx", skiprows = 4, header = [0])
df
# Out:
#       BOROUGH NEIGHBORHOOD                   BUILDING CLASS CATEGORY  \
# 0           2     BATHGATE                   01 ONE FAMILY DWELLINGS
# 1           2     BATHGATE                   01 ONE FAMILY DWELLINGS
# 2           2     BATHGATE                   01 ONE FAMILY DWELLINGS
# 3           2     BATHGATE                   01 ONE FAMILY DWELLINGS
# 4           2     BATHGATE                   02 TWO FAMILY DWELLINGS
# ...       ...          ...                                       ...
# 5601        2     WOODLAWN            10 COOPS - ELEVATOR APARTMENTS
# 5602        2     WOODLAWN            10 COOPS - ELEVATOR APARTMENTS
# 5603        2     WOODLAWN            10 COOPS - ELEVATOR APARTMENTS
# 5604        2     WOODLAWN                        22 STORE BUILDINGS
# 5605        2     WOODLAWN  35 INDOOR PUBLIC AND CULTURAL FACILITIES
#
#      TAX CLASS AT PRESENT  BLOCK  LOT  EASEMENT BUILDING CLASS AT PRESENT  \
# ...
